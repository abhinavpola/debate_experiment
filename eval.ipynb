# %%
import pandas as pd

df = pd.read_csv("debate.csv")

df.head()
# Out:
#    Debate Number                                              Topic  \
# 0              1  Forms of Government: Democracy vs. Autocracy v...
# 1              2  Forms of Government: Democracy vs. Autocracy v...
# 2              3  Forms of Government: Democracy vs. Autocracy v...
# 3              1  Electoral Systems: First Past the Post vs. Pro...
# 4              2  Electoral Systems: First Past the Post vs. Pro...
#
#                Player 1 Stance              Player 2 Stance  \
# 0                    democracy                    autocracy
# 1                    autocracy                  technocracy
# 2                  technocracy                    democracy
# 3          first past the post  proportional representation
# 4  proportional representation         ranked choice voting
#
#         Player 3 Stance                                       Conversation  \
# 0           technocracy  Player 1: Democracy is the most effective form...
# ...
